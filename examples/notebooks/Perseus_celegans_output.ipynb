# %%
import os, sys
import networkx as nx
sys.path.append('../../../')
import Holes as ho
import pickle as pk
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# Read the network in a graph object:

# %%
G = nx.read_weighted_edgelist('../datasets/celegans_weighted_undirected.edges')

# %%
fil = ho.filtrations.standard_weight_clique_rank_filtration(G)
# Out:
# Preliminary scan of edge weights to define filtration steps...
# Constructing filtration...
# Max filtration value: 30
# Clique dictionary created.

# %%
outfile = 'output_celegans/perseus_filtration_file.txt'
if os.path.exists(outfile):
    os.remove(outfile);
ho.write_perseus_filtration(fil,outfile)

# %%
ho.calculate_perseus_intervals(outfile,'output_celegans/',perseus_path='/Users/lordgrilo/Dropbox/Tools/perseus/perseusMac');

# %%
intervals = pk.load(open('output_celegans/generators_3.pck'))

# %%
fig = plt.figure(figsize=(10,10))
import numpy as np
ho.complete_persistence_diagram(intervals[1])
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
